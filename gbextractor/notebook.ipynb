# %%
from bs4 import BeautifulSoup
import requests

# %%
ENDPOINT = "https://en.1jour-1jeu.com/rules/search?page=1"

# %%
r = requests.get(ENDPOINT)

# %%
r.content
# Out:
# b'<!DOCTYPE html>\n<!--\n ___    _                    ___    _\n/_  |  (_)                  /_  |  (_)\n  | |  | | ____ _   _ _ __    | |  | | ___  _   _\n  | |_ | |/ _  \\ | | | \'__/   | |_ | |/ _ \\| | | |\n  | | |/ | (_) | |_| | |      | | |/ |  __/| |_| |\n  |_|\\___|\\____/\\____/_|      |_|\\___|\\___|\\_____/\n\n-->\n<html lang="en"><head><title>Rulebooks - 1jour-1jeu.com</title><meta charset="UTF-8"><meta name="viewport" content="width=device-width, initial-scale=1, shrink-to-fit=no" /><meta name="theme-color" content="#337ab7" /><meta name="color-scheme" content="light dark" /><meta name="msapplication-TileColor" content="#337ab7" /><meta name="description" content="All the rules of the game : Looking for a game rule? You are in the right place. Filter, sort and find your rule among thousands of referenced rules. (1jour-1jeu.com)" /><meta property="fb:app_id" content="149872872397227" /><meta property="og:url" content="https://en.1jour-1jeu.com/rules/search" /><meta propert
# ...

# %%
soup = BeautifulSoup(r.content, "html5lib")

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <!--
#  ___    _                    ___    _
# /_  |  (_)                  /_  |  (_)
#   | |  | | ____ _   _ _ __    | |  | | ___  _   _
#   | |_ | |/ _  \ | | | '__/   | |_ | |/ _ \| | | |
#   | | |/ | (_) | |_| | |      | | |/ |  __/| |_| |
#   |_|\___|\____/\____/_|      |_|\___|\___|\_____/
#
# -->
# <html lang="en">
#  <head>
#   <title>
#    Rulebooks - 1jour-1jeu.com
#   </title>
#   <meta charset="utf-8"/>
#   <meta content="width=device-width, initial-scale=1, shrink-to-fit=no" name="viewport"/>
#   <meta content="#337ab7" name="theme-color"/>
#   <meta content="light dark" name="color-scheme"/>
#   <meta content="#337ab7" name="msapplication-TileColor"/>
#   <meta content="All the rules of the game : Looking for a game rule? You are in the right place. Filter, sort and find your rule among thousands of referenced rules. (1jour-1jeu.com)" name="description"/>
#   <meta content="149872872397227" property="fb:app_id"/>
# ...

# %%
soup.find_all(class="btn btn-sm btn-secondary mb-1")
